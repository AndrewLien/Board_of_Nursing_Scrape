# %% [markdown]
# **Objective**: Scrape license data from the [Arkansas StateBoard of Nursing website]( https://www.ark.org/arsbn/statuswatch/index.php/nurse/search) for all nurses who have names that contain 'zach'.
# 1. Automate search for 'zach'.
# 2. Loop through pages
#     - Keep hitting 'Next >' until that button is no longer there (try/except)
# 3. Loop through rows
#     - Click name, retrieve element info, go bac to search results
# 4. Organize data into dataframe and export as .csv

# %%
import requests # raw data
from selenium import webdriver # webpage automation
import pandas as pd # dataframe organization

# %%
# Open chrome and navigate to page
browser = webdriver.Chrome('C:/webdrivers/chromedriver')
url = 'https://www.ark.org/arsbn/statuswatch/index.php/nurse/search'
browser.get(url)

# %%
# Search for 'zach'
search = browser.find_element_by_xpath('//*[@id="nurse_search"]/table/tbody/tr[3]/td[2]/input')
search.send_keys('zach')
searchButton = browser.find_element_by_xpath('//*[@id="nurse_search"]/table/tbody/tr[5]/td[2]/input')
searchButton.click()

# %%
# Find how many pages of results there are to see how many times to click 'Next >'
click_next_count = len(browser.find_elements_by_xpath('//*[@id="main_content"]/div[2]/center/a'))

# %%
# Initialize dataframe
column_names = ['License Number', 'Name', 'License Status', 'License Type', 'Expiration Date']
data=pd.DataFrame(columns = column_names)

# %%
# Scrape by looping by row, then by page.
for page in range(0, click_next_count):
    for row in range(1, len(browser.find_elements_by_xpath('//*[@id="main_content"]/table/tbody/tr')) + 1):
        rowxpath = '//*[@id="main_content"]/table/tbody/tr[' + str(row) + ']/td[1]/a'
        browser.find_element_by_xpath(rowxpath).click() # Clicks on next name
        data = data.append(pd.DataFrame([browser.find_element_by_xpath('//*[@id="main_content"]/div[4]/h2').text[11:],
                   browser.find_element_by_xpath('//*[@id="nurse_watch_view"]/div/table/tbody/tr/td[1]/div/strong').text,
                   browser.find_element_by_xpath('//*[@id="main_content"]/div[4]/table/tbody/tr[1]/td[2]').text,
                   browser.find_element_by_xpath('//*[@id="main_content"]/div[4]/table/tbody/tr[2]/td[2]').text,
                   browser.find_element_by_xpath('//*[@id="main_content"]/div[4]/table/tbody/tr[6]/td[2]').text], index = data.columns).T)
        browser.back() # Back to page with list of names
    try:
        browser.find_element_by_partial_link_text('Next >').click()
    except:
        print('End of search')
# Out:
# End of search

# %%
data.index = range(1,len(data)+1)
data.to_csv('license_data_zach.csv')
pd.read_csv('license_data_zach.csv', index_col = 0) # Check
# Out:
#                                        License Number  \
# 1                                             R088591
# 2                                          RTP-018807
# 3                                             C000800
# 4   Temporary Permit(Temporary Registered Nurse Pe...
# 5                                          RTP-008989
# 6                                          RTP-017195
# 7                                             R093702
# 8                                             L049670
# 9                                             R105466
# 10                                            R086376
# 11  Temporary Permit(Temporary Licensed Practical ...
# 12                                         RTP-015957
# 13                                         RTP-008141
# 14                                         LTP-009771
# 15                                         RTP-017652
# 16                                            R090910
# 17                                            L052294
# 18                                            L050899
# 19                                            R095753
# 20                                         RTP-003793
# 21                                         LTP-006360
# 22                                            R103688
# 23                                            R098648
# 24                                            R095003
# 25                                         RTP-019179
# 26                                            R103180
# 27                                            R102748
# 28                                         RTP-020890
# 29                                            L056761
# 30                                         LTP-010198
# 31                                            R096055
# 32                                         RTP-020878
# 33                                         RTP-014422
# 34                                         RTP-019851
# 35                                            R049875
# 36                                            L019329
# 37                                            L034209
# 38                                            R054440
# 39                                            R004762
# 40                                            R041058
# 41                                            R084163
#
#                          Name       License Status  \
# 1   ZACHARY T HUNTER BRANSCUM               Active
# 2   ZACHARY MATTHEW LEE BROWN          Null & Void
# 3         ZACHARY KIM BURNETT              Expired
# 4         ZACHARY WYATT CAGLE          Null & Void
# 5        ZACHARY TODD CALVERT          Null & Void
# 6         ZACHARY DILLARD COX          Null & Void
# 7          ZACHARY ALAN DAVIS               Active
# 8         ZACHARY AARON ESTES               Active
# 9       ZACHARY JAMES GEILING               Active
# 10     ZACHARY WILLIAM GODWIN               Active
# 11       ZACHARY CAINE HATLEY          Null & Void
# 12        ZACHARY WYNN HELTON          Null & Void
# 13          ZACHARY RAY HINES          Null & Void
# 14        ZACHARY WAYNE HOBBS          Null & Void
# 15        ZACHARY JAMES HUBER          Null & Void
# 16              ZACHARY MABRY               Active
# 17      ZACHARY PAUL MCDANIEL              Expired
# 18   ZACHARIAH EVANS MCNAMARA               Active
# 19         ZACHARY TEAL MESKO               Active
# 20      ZACHARY DUSTIN PIERCE          Null & Void
# 21        ZACHARY LANE PIPPEN          Null & Void
# 22   ZACHARY ELLIOTT PREZOTTI               Active
# 23        ZACHARY RYAN PRIEST              Expired
# 24        ZACHARY VAUGHN REED               Active
# 25      ZACHARY DILLON RHODES          Null & Void
# 26    ZACHARY ALEXANDER ROEHL               Active
# 27      ZACHARY JOSEPH SEFTON              Expired
# 28          ZACHARY AARON SIX          Null & Void
# 29   ZACHERY MICHAEL THIELMAN              Expired
# 30     ZACHARY DARRELL THOMAS          Null & Void
# 31       ZACHARY GRANT TURNER               Active
# 32           ZACHARY LEE WEBB          Null & Void
# 33            ZACHARY WOERNER          Null & Void
# 34        ZACHARY GRANT YAZZA          Null & Void
# 35         DIANNA FAY ZACHARY              Expired
# 36      JANICE ELAINE ZACHARY              Expired
# 37       JESSICA ANNE ZACHARY  Voluntary Surrender
# 38        JULIE MARIE ZACHARY               Active
# 39      MYRTLE CAZORT ZACHARY              Expired
# 40    SUSAN ELIZABETH ZACHARY             Inactive
# 41             DIANE J ZACHER             Inactive
#
#                                      License Type Expiration Date
# 1                           Registered Nurse (RN)      01-31-2020
# 2               Temporary Registered Nurse Permit      06-29-2016
# 3   Certified Registered Nurse Anesthetist (CRNA)      10-01-1994
# 4               Temporary Registered Nurse Permit      06-23-2006
# 5               Temporary Registered Nurse Permit      04-14-2011
# 6               Temporary Registered Nurse Permit      09-02-2015
# 7                           Registered Nurse (RN)      08-31-2020
# 8                  Licensed Practical Nurse (LPN)      12-31-2019
# 9                           Registered Nurse (RN)      12-31-2019
# 10                          Registered Nurse (RN)      07-31-2019
# 11      Temporary Licensed Practical Nurse Permit      03-26-2018
# 12              Temporary Registered Nurse Permit      10-23-2014
# 13              Temporary Registered Nurse Permit      10-08-2010
# 14      Temporary Licensed Practical Nurse Permit      12-29-2016
# 15              Temporary Registered Nurse Permit      11-16-2015
# 16                          Registered Nurse (RN)      07-31-2020
# 17                 Licensed Practical Nurse (LPN)      07-31-2013
# 18                 Licensed Practical Nurse (LPN)      02-28-2020
# 19                          Registered Nurse (RN)      05-31-2019
# 20              Temporary Registered Nurse Permit      07-14-2008
# 21      Temporary Licensed Practical Nurse Permit      11-28-2017
# 22                          Registered Nurse (RN)      09-30-2019
# 23                          Registered Nurse (RN)      01-31-2018
# 24                          Registered Nurse (RN)      11-30-2019
# 25              Temporary Registered Nurse Permit      08-09-2016
# 26                          Registered Nurse (RN)      07-31-2020
# 27                          Registered Nurse (RN)      07-31-2018
# 28              Temporary Registered Nurse Permit      06-30-2017
# 29                 Licensed Practical Nurse (LPN)      07-31-2018
# 30      Temporary Licensed Practical Nurse Permit      07-18-2017
# 31                          Registered Nurse (RN)      03-31-2020
# 32              Temporary Registered Nurse Permit      09-06-2017
# 33              Temporary Registered Nurse Permit      02-11-2014
# 34              Temporary Registered Nurse Permit      01-09-2017
# 35                          Registered Nurse (RN)      08-31-1998
# 36                 Licensed Practical Nurse (LPN)      01-31-2000
# 37                 Licensed Practical Nurse (LPN)      12-31-1997
# 38                          Registered Nurse (RN)      01-31-2020
# 39                          Registered Nurse (RN)      02-28-1989
# 40                          Registered Nurse (RN)      07-31-1996
# 41                          Registered Nurse (RN)      07-21-2011
