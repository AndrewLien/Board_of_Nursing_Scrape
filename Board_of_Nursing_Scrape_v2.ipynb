# %% [markdown]
# **Objective**: Scrape license data from the [Arkansas StateBoard of Nursing website]( https://www.ark.org/arsbn/statuswatch/index.php/nurse/search) for all nurses who have names that contain 'zach'. Scrape all licenses, not only only the first of each name.
#
# 1. Automate search for 'zach'.
# 2. Loop through pages
#     - Keep hitting 'Next >' until that button is no longer there (try/except)
# 3. Loop through rows
#     - Click name, retrieve element info, go bac to search results
# 4. Loop through licenses on each nurse's link
#     - Instead of starting xpath from main content, start from the class associated with license tables
# 4. Organize data into dataframe and export as .csv

# %%
import requests # raw data
from selenium import webdriver # webpage automation
import pandas as pd # dataframe organization

# %%
# Open chrome and navigate to page
browser = webdriver.Chrome('C:/webdrivers/chromedriver')
url = 'https://www.ark.org/arsbn/statuswatch/index.php/nurse/search'
browser.get(url)

# %%
# Search for 'zach'
search = browser.find_element_by_xpath('//*[@id="nurse_search"]/table/tbody/tr[3]/td[2]/input')
search.send_keys('zach')
searchButton = browser.find_element_by_xpath('//*[@id="nurse_search"]/table/tbody/tr[5]/td[2]/input')
searchButton.click()

# %%
# Find how many pages of results there are to see how many times to click 'Next >'
click_next_count = len(browser.find_elements_by_xpath('//*[@id="main_content"]/div[2]/center/a'))

# %%
# Initialize dataframe
column_names = ['License Number', 'Name', 'License Status', 'License Type', 'Expiration Date']
data = pd.DataFrame(columns = column_names)

# %%
for page in range(0, click_next_count):
    
    for row in range(1, len(browser.find_elements_by_xpath('//*[@id="main_content"]/table/tbody/tr')) + 1):
        
        # Clicks on next name
        rowxpath = '//*[@id="main_content"]/table/tbody/tr[' + str(row) + ']/td[1]/a'
        browser.find_element_by_xpath(rowxpath).click() 
        
        # Finds number of licenses associated with this name
        lic_qty = len(browser.find_elements_by_xpath("//div[@class = 'license_table box form']"))
        
        # Loop through licenses per nurse page
        for x in range(0,lic_qty): 
            data = data.append(pd.DataFrame([
                browser.find_elements_by_xpath('//*[@class="license_table box form"]/h2')[x].text, # licnum
                browser.find_element_by_xpath('//*[@id="nurse_watch_view"]/div/table/tbody/tr/td[1]/div/strong').text, # name
                browser.find_elements_by_xpath('//*[@class="license_table box form"]/table/tbody/tr[1]/td[2]')[x].text, # status
                browser.find_elements_by_xpath('//*[@class="license_table box form"]/table/tbody/tr[2]/td[2]')[x].text, # type
                browser.find_elements_by_xpath('//*[@class="license_table box form"]/table/tbody/tr[6]/td[2]')[x].text # expdate
            ], index = data.columns).T)
        
        # Back to page with list of names
        browser.back() 
    
    try:
        browser.find_element_by_partial_link_text('Next >').click()
    except:
        print('End of search')
# Out:
# End of search

# %%
data.index = range(1,len(data)+1)
data.to_csv('license_data_zach_v2.csv')
pd.read_csv('license_data_zach_v2.csv', index_col = 0) # Check
# Out:
#                                        License Number  \
# 1                                  License #: R088591
# 2                               License #: RTP-009225
# 3                               License #: RTP-018807
# 4                                  License #: R101512
# 5                                  License #: C000800
# 6                                  License #: R039861
# 7   License #: Temporary Permit(Temporary Register...
# 8                                  License #: R076951
# 9                               License #: RTP-008989
# 10                                 License #: R088351
# 11                              License #: RTP-017195
# 12                                 License #: R099559
# 13                                 License #: L056282
# 14                                 License #: R093702
# 15                                 License #: L049670
# 16                              License #: LTP-003569
# 17                                 License #: R105466
# 18                                 License #: R086376
# 19  License #: Temporary Permit(Temporary Licensed...
# 20                                 License #: L046086
# 21                              License #: RTP-015957
# 22                                 License #: R097281
# 23                              License #: RTP-008141
# 24                                 License #: R087666
# 25                              License #: LTP-009771
# 26                                 License #: L058422
# 27                              License #: RTP-017652
# 28                                 License #: R099929
# 29                                 License #: R090910
# 30                                 License #: L052294
# ..                                                ...
# 43                              License #: RTP-016841
# 44                                 License #: R095003
# 45                              License #: RTP-014236
# 46                              License #: RTP-019179
# 47                                 License #: R102141
# 48                                 License #: R103180
# 49                                 License #: R102748
# 50                              License #: RTP-020890
# 51                                 License #: R104702
# 52                                 License #: L056761
# 53                                 License #: R102838
# 54                              License #: LTP-008779
# 55                              License #: LTP-010198
# 56                                 License #: R096055
# 57                              License #: RTP-020878
# 58                                 License #: L053041
# 59                              License #: RTP-014422
# 60                                 License #: R095847
# 61                              License #: RTP-019851
# 62                                 License #: R103631
# 63                                 License #: R049875
# 64                                 License #: C000956
# 65                                 License #: L019329
# 66                                 License #: L034209
# 67                                 License #: R053169
# 68                                 License #: R054440
# 69                                 License #: L022290
# 70                                 License #: R004762
# 71                                 License #: R041058
# 72                                 License #: R084163
#
#                          Name       License Status  \
# 1   ZACHARY T HUNTER BRANSCUM               Active
# 2   ZACHARY T HUNTER BRANSCUM          Null & Void
# 3   ZACHARY MATTHEW LEE BROWN          Null & Void
# 4   ZACHARY MATTHEW LEE BROWN               Active
# 5         ZACHARY KIM BURNETT              Expired
# 6         ZACHARY KIM BURNETT             Inactive
# 7         ZACHARY WYATT CAGLE          Null & Void
# 8         ZACHARY WYATT CAGLE            Probation
# 9        ZACHARY TODD CALVERT          Null & Void
# 10       ZACHARY TODD CALVERT               Active
# 11        ZACHARY DILLARD COX          Null & Void
# 12        ZACHARY DILLARD COX               Active
# 13        ZACHARY DILLARD COX              Expired
# 14         ZACHARY ALAN DAVIS               Active
# 15        ZACHARY AARON ESTES               Active
# 16        ZACHARY AARON ESTES          Null & Void
# 17      ZACHARY JAMES GEILING               Active
# 18     ZACHARY WILLIAM GODWIN               Active
# 19       ZACHARY CAINE HATLEY          Null & Void
# 20       ZACHARY CAINE HATLEY               Active
# 21        ZACHARY WYNN HELTON          Null & Void
# 22        ZACHARY WYNN HELTON               Active
# 23          ZACHARY RAY HINES          Null & Void
# 24          ZACHARY RAY HINES               Active
# 25        ZACHARY WAYNE HOBBS          Null & Void
# 26        ZACHARY WAYNE HOBBS               Active
# 27        ZACHARY JAMES HUBER          Null & Void
# 28        ZACHARY JAMES HUBER              Expired
# 29              ZACHARY MABRY               Active
# 30      ZACHARY PAUL MCDANIEL              Expired
# ..                        ...                  ...
# 43        ZACHARY RYAN PRIEST          Null & Void
# 44        ZACHARY VAUGHN REED               Active
# 45        ZACHARY VAUGHN REED          Null & Void
# 46      ZACHARY DILLON RHODES          Null & Void
# 47      ZACHARY DILLON RHODES               Active
# 48    ZACHARY ALEXANDER ROEHL               Active
# 49      ZACHARY JOSEPH SEFTON              Expired
# 50          ZACHARY AARON SIX          Null & Void
# 51          ZACHARY AARON SIX               Active
# 52   ZACHERY MICHAEL THIELMAN              Expired
# 53   ZACHERY MICHAEL THIELMAN               Active
# 54   ZACHERY MICHAEL THIELMAN          Null & Void
# 55     ZACHARY DARRELL THOMAS          Null & Void
# 56       ZACHARY GRANT TURNER               Active
# 57           ZACHARY LEE WEBB          Null & Void
# 58           ZACHARY LEE WEBB               Active
# 59            ZACHARY WOERNER          Null & Void
# 60            ZACHARY WOERNER               Active
# 61        ZACHARY GRANT YAZZA          Null & Void
# 62        ZACHARY GRANT YAZZA               Active
# 63         DIANNA FAY ZACHARY              Expired
# 64         DIANNA FAY ZACHARY              Expired
# 65      JANICE ELAINE ZACHARY              Expired
# 66       JESSICA ANNE ZACHARY  Voluntary Surrender
